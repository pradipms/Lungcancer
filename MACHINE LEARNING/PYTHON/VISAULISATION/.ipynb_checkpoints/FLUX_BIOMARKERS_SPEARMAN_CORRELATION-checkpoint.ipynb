# %%
# Importing the libraries
import numpy as np
import pandas as pd
import os

# %%
os.chdir('C:\\Users\\U0033207PC\\Desktop\\GENE Enrichment\\FINAL VISUALISATION')

# %%
# Importing the dataset
dt = pd.read_excel('FLUX_BIOMARKERS_CORRELATION.xlsx')

# %%
dt.head(2)
# Out:
#        HUG0_SYMBOL   FACOAL161  FACOAL226  FAOXC180x  FAOXC200180x  \
# 0  TCGA-05-4244-01  492.278261   7.079644  72.493260     72.493260
# 1  TCGA-05-4249-01  310.135139  -9.551541  56.620656     56.620656
#
#         LPS2e  FAOXC22C20x  FAOXC5C5OHm       FOLR2      MTHFC      MTHFD2  \
# 0   61.853054    73.132205    738.25540  108.397948  270.35413   56.871599
# 1  140.936419    56.620656    652.09649   48.449442  382.29994  161.789575
#
#        MTHFDm      MTHFR3          PGI         GAPD       LDH_L          PGK  \
# 0 -297.748823  140.623096 -1030.983679  1166.701897  762.687695 -1166.701897
# 1 -167.948581   53.053610  -948.109309   597.786527  205.141506  -597.786527
#
#           PGM  Overall Survival (Months)
# 0 -749.960368                       0.00
# 1 -631.433024                      50.03

# %%
dt_ = dt.drop('HUG0_SYMBOL', axis=1)
X = dt_

# %%
X
# Out:
#       FACOAL161  FACOAL226   FAOXC180x  FAOXC200180x       LPS2e  FAOXC22C20x  \
# 0    492.278261   7.079644   72.493260     72.493260   61.853054    73.132205
# 1    310.135139  -9.551541   56.620656     56.620656  140.936419    56.620656
# 2    469.075416   7.079644   16.444642     16.444642  141.025689    16.444642
# 3    388.931756  -2.566599   57.663478     57.663478  143.147092    57.663478
# 4    370.985877 -14.063856   55.165456     55.165456  234.667633    55.165456
# ..          ...        ...         ...           ...         ...          ...
# 512  414.746889  39.822528   85.618963     85.618963   36.750627    85.618963
# 513  417.138336   5.666023   58.185536     58.185536  155.813294    58.185536
# 514  399.975731  10.625324   79.222673     79.222673  218.430669    79.222673
# 515  353.756675  31.685559  101.809065    101.809065   37.588203   101.809065
# 516  407.734630  21.466950   74.585330     74.585330  134.348243    74.585330
#
#      FAOXC5C5OHm       FOLR2       MTHFC      MTHFD2      MTHFDm      MTHFR3  \
# 0     738.255400  108.397948  270.354130   56.871599 -297.748823  140.623096
# 1     652.096490   48.449442  382.299940  161.789575 -167.948581   53.053610
# 2     702.829701   96.069113  238.709350   36.999800 -351.986493   74.714500
# 3     672.085332   45.966676  411.693304  166.922048 -189.198139   52.530859
# 4     803.016266   94.298178  270.281991   91.494424 -194.522383  107.434150
# ..           ...         ...         ...         ...         ...         ...
# 512   982.765609   53.142165  471.778643  204.275030 -173.381863   45.813064
# 513   681.128567   76.246064  333.915439   97.177495 -164.715325   62.740789
# 514   937.183116   87.093217  424.185618  176.119543 -205.556957   89.315335
# 515   664.991168   35.862855  250.687797   82.514729 -185.908601   48.979057
# 516   812.284820   55.135222  522.125514  236.022182 -239.461405   28.319595
#
#              PGI         GAPD       LDH_L          PGK          PGM  \
# 0   -1030.983679  1166.701897  762.687695 -1166.701897  -749.960368
# 1    -948.109309   597.786527  205.141506  -597.786527  -631.433024
# 2    -928.460497   736.258582  586.017733  -736.258582  -976.578815
# 3   -1229.347764   827.567914  196.688284  -827.567914 -1051.613598
# 4    -742.146537   751.875531  227.911782  -751.875531  -707.795001
# ..           ...          ...         ...          ...          ...
# 512  -965.506263   634.227530  254.176292  -634.227530  -630.853194
# 513 -1044.786548  1278.991740  139.576351 -1278.991740 -1278.991740
# 514  -639.692375   849.096140  210.100092  -849.096140  -772.860595
# 515  -778.249485   716.548423  240.272144  -716.548423  -723.350977
# 516  -632.873390   694.539999  225.475187  -694.539999  -722.831117
#
#      Overall Survival (Months)
# 0                         0.00
# 1                        50.03
# 2                         3.98
# 3                        19.94
# 4                        13.99
# ..                         ...
# 512                       0.43
# 513                      19.81
# 514                      20.27
# 515                      59.07
# 516                      16.85
#
# [517 rows x 18 columns]

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
dt1 = sc_X.fit_transform(X)

# %%
dt1
# Out:
# array([[ 1.00188002e+00, -2.54921973e-16,  2.56731455e-15, ...,
#         -7.67023404e-01,  4.21899917e-01, -1.02255651e+00],
#        [-9.60172955e-01, -9.54685328e-01, -7.16880998e-01, ...,
#          8.32704290e-01,  7.97060718e-01,  6.94220514e-01],
#        [ 7.51938041e-01, -2.54921973e-16, -2.53141763e+00, ...,
#          4.43336042e-01, -2.95389064e-01, -8.85983000e-01],
#        ...,
#        [ 7.59348108e-03,  2.03533813e-01,  3.03931733e-01, ...,
#          1.26049190e-01,  3.49416494e-01, -3.26992441e-01],
#        [-4.90280034e-01,  1.41246136e+00,  1.32403881e+00, ...,
#          4.98758851e-01,  5.06123524e-01,  1.00442767e+00],
#        [ 9.11726575e-02,  8.25879196e-01,  9.44876317e-02, ...,
#          5.60644129e-01,  5.07768978e-01, -4.44349575e-01]])

# %%
df = pd.DataFrame(dt1, columns = ['FACOAL161','FACOAL226','FAOXC180x','FAOXC200180x','LPS2e','FAOXC22C20x','FAOXC5C5OHm','FOLR2','MTHFC','MTHFD2','MTHFDm','MTHFR3','PGI','GAPD','LDH_L','PGK','PGM','Overall Survival (Months)'])

# %%
FLUX_BIOMARKER_CORRELATION = df[df.columns[:]].corr()['Overall Survival (Months)'][:]

# %%
FLUX_BIOMARKER_CORRELATION
# Out:
# FACOAL161                   -0.095120
# FACOAL226                    0.064798
# FAOXC180x                   -0.005710
# FAOXC200180x                -0.005710
# LPS2e                       -0.069126
# FAOXC22C20x                  0.008802
# FAOXC5C5OHm                 -0.010555
# FOLR2                       -0.118488
# MTHFC                       -0.007334
# MTHFD2                       0.041264
# MTHFDm                       0.068427
# MTHFR3                      -0.100520
# PGI                          0.086160
# GAPD                        -0.119948
# LDH_L                       -0.060125
# PGK                          0.118949
# PGM                          0.072755
# Overall Survival (Months)    1.000000
# Name: Overall Survival (Months), dtype: float64

# %%
FLUX_BIOMARKER_CORRELATION.to_csv(r'C:\Users\U0033207PC\Desktop\GENE Enrichment\FINAL VISUALISATION\PLOTS\FLUX_BIOMARKER_CORRELATION.csv')
