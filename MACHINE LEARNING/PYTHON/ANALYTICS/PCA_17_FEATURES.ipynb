# %%
#importing necessary python packages
import pandas as pd
import os

# %%
#setting the right directory
os.chdir('C:\\Users\\U0033207PC\\Desktop\\GENE Enrichment')

# %%
# Importing the dataset
dt = pd.read_excel('FLUX.xlsx')

# %%
dt.head()
# Out:
#        HUG0_SYMBOL     3DSPHR   3HBCOAHLm      ABTArm       ABTD     ACACT1r  \
# 0  TCGA-05-4244-01  11.448262  154.187481 -583.764387 -14.237357  125.403072
# 1  TCGA-05-4249-01   9.173955  162.200877 -442.863722  -5.338254  128.134267
# 2  TCGA-05-4250-01  11.167238   96.659688 -661.410699 -14.973614  185.149045
# 3  TCGA-05-4382-01   9.813735  152.832310 -413.172469  -7.077201  198.790709
# 4  TCGA-05-4384-01  10.017708  146.338416 -483.996897  -7.935740  151.432371
#
#      ACACT1rm     ACACT1x    ACOAD9m    ACOAO7p  ...  1513TACRitr  \
# 0  235.338244  457.654536  74.716367  72.493260  ...    14.770344
# 1  137.492687  149.939274  75.026103  56.620656  ...    34.017476
# 2  192.183642  403.670235  74.716367  16.444642  ...    16.855148
# 3  137.492687  161.066009  68.272577  57.663478  ...    30.635114
# 4   58.691049  170.595446  52.965875  55.165456  ...    58.143309
#
#    1531TACRitr  DEOXFVSitx      FVSitx     TACRitr   13DMTitr   15DMTitr  \
# ...

# %%
dt1 = dt[['3DSPHR','3HBCOAHLm','ABTArm','ABTD','ACACT1r','ACACT1rm','ACACT1x','ACOAD9m','ACOAO7p','ACOATA','ACONT','ACONTm','ADK1','ADK1m','ADK3','ADK3m','ADKd'
]]

# %%
dt1.head()
# Out:
#       3DSPHR   3HBCOAHLm      ABTArm       ABTD     ACACT1r    ACACT1rm  \
# 0  11.448262  154.187481 -583.764387 -14.237357  125.403072  235.338244
# 1   9.173955  162.200877 -442.863722  -5.338254  128.134267  137.492687
# 2  11.167238   96.659688 -661.410699 -14.973614  185.149045  192.183642
# 3   9.813735  152.832310 -413.172469  -7.077201  198.790709  137.492687
# 4  10.017708  146.338416 -483.996897  -7.935740  151.432371   58.691049
#
#       ACACT1x    ACOAD9m    ACOAO7p      ACOATA       ACONT      ACONTm  \
# 0  457.654536  74.716367  72.493260 -165.591744 -262.168409 -248.527251
# 1  149.939274  75.026103  56.620656  -73.252506 -257.239413 -248.795522
# 2  403.670235  74.716367  16.444642 -176.456428 -252.322873 -207.031983
# 3  161.066009  68.272577  57.663478  -83.597986 -253.712853 -259.439380
# 4  170.595446  52.965875  55.165456  -87.272646 -203.961933 -206.877844
#
#           ADK1       ADK1m         ADK3       ADK3m        ADKd
# ...

# %%
dt1.to_csv(r'C:\Users\U0033207PC\Desktop\GENE Enrichment\FINAL VISUALISATION\ANALYTICS\FLUX_17_FEATURES.csv')
