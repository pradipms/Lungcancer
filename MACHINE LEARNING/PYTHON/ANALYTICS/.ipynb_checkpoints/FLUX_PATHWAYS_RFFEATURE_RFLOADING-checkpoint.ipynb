# %%
#importing necessary python packages
import pandas as pd
import numpy as np
from bioinfokit.visuz import cluster
import os

# %%
#setting the right directory
os.chdir('C:\\Users\\U0033207PC\\Desktop\\GENE Enrichment\\FINAL VISUALISATION\\ANALYTICS')

# %%
# Importing the dataset
dt = pd.read_csv('PCA_PATHWAYS.csv')

# %%
dt = dt.drop('HUG0_SYMBOL', axis=1)

# %%
X = dt.iloc[:,0:16]

# %%
target = dt['OverallSurvivalMonths']

# %%
from sklearn.preprocessing import StandardScaler
X_sd = StandardScaler().fit_transform(X)

# %%
pd.DataFrame(X_sd, columns=X.columns).head()
# Out:
#    Alanine, aspartate and glutamate metabolism                              \
# 0                                           0.653725
# 1                                          -0.391355
# 2                                           1.229639
# 3                                          -0.611580
# 4                                          -0.086265
#
#    D-Glutamine and D-glutamate metabolism     \
# 0                                   0.653725
# 1                                  -0.391355
# 2                                   1.229639
# 3                                  -0.611580
# 4                                  -0.086265
#
#    Amino sugar and nucleotide sugar metabolism  Butanoate metabolism  \
# 0                                    -0.833196             -0.916036
# 1                                    -0.627808             -0.880922
# 2                                    -0.404712             -0.147911
# 3                                     1.617885              0.027474
# 4                                    -0.302677             -0.581390
#
#    Cholesterol metabolism  \
# 0                3.149380
# 1               -0.970449
# 2                2.426614
# 3               -0.821479
# 4               -0.693895
#
#    Fatty acid biosynthesis                                                \
# 0                                           0.873906
# 1                                          -0.734944
# 2                                           1.083559
# 3                                          -0.853150
# 4                                          -0.388144
#
#    Biosynthesis of unsaturated fatty acids   \
# 0                                  0.873906
# 1                                 -0.734944
# 2                                  1.083559
# 3                                 -0.853150
# 4                                 -0.388144
#
#    Glycine, serine and threonine metabolism  \
# 0                                  0.873906
# 1                                 -0.734944
# 2                                  1.083559
# 3                                 -0.853150
# 4                                 -0.388144
#
#    Glyoxylate and dicarboxylate metabolism  \
# 0                                 0.804274
# 1                                 0.752880
# 2                                 0.238132
# 3                                 0.831363
# 4                                -0.296851
#
#    Pentose and glucuronate interconversions                      \
# 0                                           0.431047
# 1                                          -0.378632
# 2                                           0.498034
# 3                                          -0.220415
# 4                                          -0.142301
#
#    Pentose phosphate pathway  Purine metabolism  Sphingolipid metabolism  \
# 0                   0.431047           0.872910                 1.262181
# 1                  -0.378632          -0.584812                -0.611485
# 2                   0.498034          -1.137464                 1.030662
# 3                  -0.220415          -0.501354                -0.084408
# 4                  -0.142301           0.100648                 0.083633
#
#    Tryptophan metabolism  Valine, leucine and isoleucine degradation    \
# 0               0.255416                                      0.092146
# 1              -0.658057                                      0.261467
# 2               0.414758                                     -1.123405
# 3               0.020523                                      0.063511
# 4              -1.191110                                     -0.073703
#
#    Valine, leucine and isoleucine biosynthesis
# 0                                     0.092146
# 1                                     0.261467
# 2                                    -1.123405
# 3                                     0.063511
# 4                                    -0.073703

# %%
from sklearn.decomposition import PCA
pca_out = PCA().fit(X_sd)

# %%
# get the component variance
# Proportion of Variance 
pca_out.explained_variance_ratio_
# Out:
# array([3.70892444e-01, 1.41312334e-01, 1.23646212e-01, 9.50509927e-02,
#        7.24452086e-02, 6.41712084e-02, 5.41085146e-02, 4.03154531e-02,
#        2.32631694e-02, 1.21989935e-02, 2.59546867e-03, 3.07265935e-33,
#        1.82871400e-33, 3.14729613e-34, 2.40650632e-34, 3.25639076e-35])

# %%
# Cumulative proportion of variance 
np.cumsum(pca_out.explained_variance_ratio_)
# Out:
# array([0.37089244, 0.51220478, 0.63585099, 0.73090198, 0.80334719,
#        0.8675184 , 0.92162692, 0.96194237, 0.98520554, 0.99740453,
#        1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        ])

# %%
# get component loadings (correlation coefficient between original variables and the component) 
# the squared loadings within the PCs always sums to 1

loadings = pca_out.components_
num_pc = pca_out.n_features_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df['variable'] = X.columns.values
loadings_df = loadings_df.set_index('variable')
loadings_df
# Out:
#                                                          PC1       PC2  \
# variable
# Alanine, aspartate and glutamate metabolism    ...  0.383687 -0.080122
# D-Glutamine and D-glutamate metabolism              0.383687 -0.080122
# Amino sugar and nucleotide sugar metabolism         0.025138  0.052953
# Butanoate metabolism                               -0.077540 -0.134607
# Cholesterol metabolism                              0.200916  0.100237
# Fatty acid biosynthesis                        ...  0.398386 -0.021688
# Biosynthesis of unsaturated fatty acids             0.398386 -0.021688
# Glycine, serine and threonine metabolism            0.398386 -0.021688
# Glyoxylate and dicarboxylate metabolism             0.043926  0.197093
# Pentose and glucuronate interconversions       ...  0.199373  0.412944
# Pentose phosphate pathway                           0.199373  0.412944
# Purine metabolism                                   0.007434  0.123400
# Sphingolipid metabolism                             0.202680  0.253625
# Tryptophan metabolism                               0.086839 -0.145605
# Valine, leucine and isoleucine degradation         -0.161738  0.486896
# Valine, leucine and isoleucine biosynthesis        -0.161738  0.486896
#
#                                                          PC3       PC4  \
# variable
# Alanine, aspartate and glutamate metabolism    ... -0.130135 -0.166670
# D-Glutamine and D-glutamate metabolism             -0.130135 -0.166670
# Amino sugar and nucleotide sugar metabolism         0.041383 -0.032929
# Butanoate metabolism                                0.609440  0.010360
# Cholesterol metabolism                              0.442357  0.074549
# Fatty acid biosynthesis                        ...  0.018362 -0.144022
# Biosynthesis of unsaturated fatty acids             0.018362 -0.144022
# Glycine, serine and threonine metabolism            0.018362 -0.144022
# Glyoxylate and dicarboxylate metabolism             0.006539 -0.361925
# Pentose and glucuronate interconversions       ... -0.019107  0.447031
# Pentose phosphate pathway                          -0.019107  0.447031
# Purine metabolism                                   0.092720  0.234104
# Sphingolipid metabolism                             0.086976  0.004336
# Tryptophan metabolism                               0.603523 -0.016222
# Valine, leucine and isoleucine degradation          0.086990 -0.380602
# Valine, leucine and isoleucine biosynthesis         0.086990 -0.380602
#
#                                                          PC5       PC6  \
# variable
# Alanine, aspartate and glutamate metabolism    ...  0.100587 -0.017807
# D-Glutamine and D-glutamate metabolism              0.100587 -0.017807
# Amino sugar and nucleotide sugar metabolism        -0.234767  0.911444
# Butanoate metabolism                                0.123201  0.015783
# Cholesterol metabolism                             -0.064026 -0.035070
# Fatty acid biosynthesis                        ...  0.116579  0.014246
# Biosynthesis of unsaturated fatty acids             0.116579  0.014246
# Glycine, serine and threonine metabolism            0.116579  0.014246
# Glyoxylate and dicarboxylate metabolism            -0.374026 -0.163624
# Pentose and glucuronate interconversions       ... -0.089263 -0.112586
# Pentose phosphate pathway                          -0.089263 -0.112586
# Purine metabolism                                   0.710141  0.250157
# Sphingolipid metabolism                            -0.335835  0.187068
# Tryptophan metabolism                              -0.145116 -0.127655
# Valine, leucine and isoleucine degradation          0.187915 -0.016656
# Valine, leucine and isoleucine biosynthesis         0.187915 -0.016656
#
#                                                          PC7       PC8  \
# variable
# Alanine, aspartate and glutamate metabolism    ...  0.041493  0.108420
# D-Glutamine and D-glutamate metabolism              0.041493  0.108420
# Amino sugar and nucleotide sugar metabolism         0.202575  0.190789
# Butanoate metabolism                                0.255341  0.170504
# Cholesterol metabolism                             -0.346477 -0.252830
# Fatty acid biosynthesis                        ...  0.012098  0.046601
# Biosynthesis of unsaturated fatty acids             0.012098  0.046601
# Glycine, serine and threonine metabolism            0.012098  0.046601
# Glyoxylate and dicarboxylate metabolism             0.627186 -0.512345
# Pentose and glucuronate interconversions       ...  0.184007  0.185857
# Pentose phosphate pathway                           0.184007  0.185857
# Purine metabolism                                   0.178967 -0.519776
# Sphingolipid metabolism                            -0.502532 -0.381433
# Tryptophan metabolism                               0.076404  0.139274
# Valine, leucine and isoleucine degradation         -0.095789  0.192279
# Valine, leucine and isoleucine biosynthesis        -0.095789  0.192279
#
#                                                          PC9      PC10  \
# variable
# Alanine, aspartate and glutamate metabolism    ... -0.096897  0.047744
# D-Glutamine and D-glutamate metabolism             -0.096897  0.047744
# Amino sugar and nucleotide sugar metabolism         0.134142  0.108859
# Butanoate metabolism                               -0.118130 -0.675912
# Cholesterol metabolism                              0.710384  0.076039
# Fatty acid biosynthesis                        ...  0.047484 -0.079278
# Biosynthesis of unsaturated fatty acids             0.047484 -0.079278
# Glycine, serine and threonine metabolism            0.047484 -0.079278
# Glyoxylate and dicarboxylate metabolism             0.070329 -0.015553
# Pentose and glucuronate interconversions       ... -0.010453 -0.012885
# Pentose phosphate pathway                          -0.010453 -0.012885
# Purine metabolism                                  -0.151577  0.167720
# Sphingolipid metabolism                            -0.532300 -0.239059
# Tryptophan metabolism                              -0.355210  0.641818
# Valine, leucine and isoleucine degradation         -0.010154  0.046434
# Valine, leucine and isoleucine biosynthesis        -0.010154  0.046434
#
#                                                         PC11          PC12  \
# variable
# Alanine, aspartate and glutamate metabolism    ... -0.515820  1.383135e-01
# D-Glutamine and D-glutamate metabolism             -0.515820 -1.383135e-01
# Amino sugar and nucleotide sugar metabolism        -0.025298  3.903128e-18
# Butanoate metabolism                               -0.154384 -1.006140e-16
# Cholesterol metabolism                             -0.220505 -1.075529e-16
# Fatty acid biosynthesis                        ...  0.358359  9.974323e-02
# Biosynthesis of unsaturated fatty acids             0.358359 -7.121382e-02
# Glycine, serine and threonine metabolism            0.358359 -2.852941e-02
# Glyoxylate and dicarboxylate metabolism            -0.021823 -3.903128e-17
# Pentose and glucuronate interconversions       ... -0.014345 -1.246514e-01
# Pentose phosphate pathway                          -0.014345  1.246514e-01
# Purine metabolism                                  -0.033686 -5.290907e-17
# Sphingolipid metabolism                            -0.026656 -3.469447e-17
# Tryptophan metabolism                               0.077852  1.335737e-16
# Valine, leucine and isoleucine degradation         -0.018770  6.763242e-01
# Valine, leucine and isoleucine biosynthesis        -0.018770 -6.763242e-01
#
#                                                             PC13  \
# variable
# Alanine, aspartate and glutamate metabolism    ... -3.827838e-01
# D-Glutamine and D-glutamate metabolism              3.827838e-01
# Amino sugar and nucleotide sugar metabolism         9.627715e-17
# Butanoate metabolism                               -1.387779e-17
# Cholesterol metabolism                             -4.163336e-17
# Fatty acid biosynthesis                        ... -2.432244e-01
# Biosynthesis of unsaturated fatty acids             1.095437e-01
# Glycine, serine and threonine metabolism            1.336806e-01
# Glyoxylate and dicarboxylate metabolism             8.326673e-17
# Pentose and glucuronate interconversions       ...  5.184757e-01
# Pentose phosphate pathway                          -5.184757e-01
# Purine metabolism                                   2.255141e-17
# Sphingolipid metabolism                             6.245005e-17
# Tryptophan metabolism                              -6.938894e-18
# Valine, leucine and isoleucine degradation          2.003630e-01
# Valine, leucine and isoleucine biosynthesis        -2.003630e-01
#
#                                                             PC14  \
# variable
# Alanine, aspartate and glutamate metabolism    ...  5.737646e-01
# D-Glutamine and D-glutamate metabolism             -5.737646e-01
# Amino sugar and nucleotide sugar metabolism        -3.469447e-18
# Butanoate metabolism                                1.942890e-16
# Cholesterol metabolism                              1.804112e-16
# Fatty acid biosynthesis                        ... -1.789889e-01
# Biosynthesis of unsaturated fatty acids             1.741421e-01
# Glycine, serine and threonine metabolism            4.846836e-03
# Glyoxylate and dicarboxylate metabolism             3.469447e-18
# Pentose and glucuronate interconversions       ...  3.727143e-01
# Pentose phosphate pathway                          -3.727143e-01
# Purine metabolism                                   1.908196e-17
# Sphingolipid metabolism                            -1.804112e-16
# Tryptophan metabolism                              -5.204170e-17
# Valine, leucine and isoleucine degradation         -2.617645e-02
# Valine, leucine and isoleucine biosynthesis         2.617645e-02
#
#                                                             PC15          PC16
# variable
# Alanine, aspartate and glutamate metabolism    ... -2.994138e-02  6.514302e-02
# D-Glutamine and D-glutamate metabolism              2.994138e-02 -6.514302e-02
# Amino sugar and nucleotide sugar metabolism         1.123776e-16  1.189370e-16
# Butanoate metabolism                                2.697495e-16  1.387779e-17
# Cholesterol metabolism                              1.674008e-16 -1.682682e-16
# Fatty acid biosynthesis                        ... -6.567472e-01 -3.663413e-01
# Biosynthesis of unsaturated fatty acids             6.533688e-01 -4.386104e-01
# Glycine, serine and threonine metabolism            3.378338e-03  8.049518e-01
# Glyoxylate and dicarboxylate metabolism            -1.431147e-17  4.206704e-17
# Pentose and glucuronate interconversions       ... -2.613918e-01 -9.166984e-02
# Pentose phosphate pathway                           2.613918e-01  9.166984e-02
# Purine metabolism                                   1.266890e-16 -2.198762e-16
# Sphingolipid metabolism                            -5.117434e-17  7.806256e-17
# Tryptophan metabolism                              -1.511378e-16 -7.372575e-18
# Valine, leucine and isoleucine degradation          4.084450e-02 -9.318110e-03
# Valine, leucine and isoleucine biosynthesis        -4.084450e-02  9.318110e-03

# %%
loadings_df.to_csv(r'C:\Users\U0033207PC\Desktop\GENE Enrichment\FINAL VISUALISATION\ANALYTICS\pca_loadings_df.csv')

# %%
# positive and negative values in component loadings reflects the positive and negative correlation of the variables
# with then PCs. 

# get correlation matrix plot for loadings
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.heatmap(loadings_df, annot=True, cmap='Spectral')
plt.savefig(r'C:\Users\U0033207PC\Desktop\GENE Enrichment\FINAL VISUALISATION\ANALYTICS\PLOTS\PCA_PATHWAYS_CORRELATION.pdf', bbox_inches="tight")
plt.show()

# %%
var = loadings_df
var.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col0{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col1,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col1{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col2,#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col2,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col13,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row5_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row6_col15,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col4,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col5,#T_49433f52_e013_11eb_a88c_3417ebb72a77row10_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col7,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_col6,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row13_col1,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col11{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col3{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col4,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col4,#T_49433f52_e013_11eb_a88c_3417ebb72a77row13_col3{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col5,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col5,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col5,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col5{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col6,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col6{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col7,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col7{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col8{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row4_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col9{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col6{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col12{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col13,#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col5,#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col7,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col2,#T_49433f52_e013_11eb_a88c_3417ebb72a77row4_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row5_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row5_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row6_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row6_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row6_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row7_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row7_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row7_col15,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col6,#T_49433f52_e013_11eb_a88c_3417ebb72a77row9_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row9_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row10_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col4,#T_49433f52_e013_11eb_a88c_3417ebb72a77row13_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col1,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col7,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col1,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row7_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col13{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row0_col15{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col11{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col12{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col14{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row1_col15{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col0,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col8{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col2{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col3,#T_49433f52_e013_11eb_a88c_3417ebb72a77row9_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row10_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row14_col8,#T_49433f52_e013_11eb_a88c_3417ebb72a77row15_col8{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col4{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col6{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col8{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col9{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col10,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_col10{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row2_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col13,#T_49433f52_e013_11eb_a88c_3417ebb72a77row3_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row4_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row4_col13,#T_49433f52_e013_11eb_a88c_3417ebb72a77row4_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row7_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row8_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row9_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row10_col9,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row11_col14,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_col11,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_col12,#T_49433f52_e013_11eb_a88c_3417ebb72a77row12_co

# %%
# get eigenvalues 
pca_out.explained_variance_
# Out:
# array([5.94577965e+00, 2.26537913e+00, 1.98217339e+00, 1.52376320e+00,
#        1.16136970e+00, 1.02872914e+00, 8.67414017e-01, 6.46297342e-01,
#        3.72932049e-01, 1.95562159e-01, 4.16079784e-02, 4.92578259e-32,
#        2.93161283e-32, 5.04543287e-33, 3.85787215e-33, 5.22032256e-34])

# %%
# get scree plot (for scree or elbow test)
cluster.screeplot(obj=[pc_list, pca_out.explained_variance_ratio_])

# %%
# get PCA loadings plots (2D and 3D)
# 2D

cluster.pcaplot(x=loadings[0], y=loadings[1], labels=X.columns.values, 
var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
var2=round(pca_out.explained_variance_ratio_[1]*100, 2))

# %%
# 3D
cluster.pcaplot(x=loadings[0], y=loadings[1], z=loadings[2],  labels=X.columns.values, 
var1=round(pca_out.explained_variance_ratio_[0]*100, 2), var2=round(pca_out.explained_variance_ratio_[1]*100, 2), 
var3=round(pca_out.explained_variance_ratio_[2]*100, 2))

# %%
# get PC scores
pca_scores = PCA().fit_transform(X_sd)

# %%
# get 2D biplot
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
var2=round(pca_out.explained_variance_ratio_[1]*100, 2))

# %%
# get 3D biplot
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, 
var1=round(pca_out.explained_variance_ratio_[0]*100, 2), var2=round(pca_out.explained_variance_ratio_[1]*100, 2), 
var3=round(pca_out.explained_variance_ratio_[2]*100, 2))

# %%
# Color classes
colorlist = [{'0-30':"r",'31-60':"g",'61-90':"b", '91-120':"c", '121-150':"m", '151-180':"y", '181-210':"k", '211-240':"w"}[X] for X in target]

# %%
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2), colorlist=target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9968d796b61e> in <module>
#       1 cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
# ----> 2     var2=round(pca_out.explained_variance_ratio_[1]*100, 2), colorlist=target)
#
# c:\python\python37\lib\site-packages\bioinfokit\visuz.py in biplot(cscore, loadings, labels, var1, var2, var3, axlabelfontsize, axlabelfontname, figtype, r, show, markerdot, dotsize, valphadot, colordot, arrowcolor, valphaarrow, arrowlinestyle, arrowlinewidth, centerlines, colorlist, legendpos, datapoints, dim)
#    1271                         #                alpha=valphadot, marker=markerdot)
#    1272                         # plt.legend(handles=s.legend_elements()[0], labels=list(unique_class))
# -> 1273                         s = plt.scatter(cscore[:, 0] * xscale, cscore[:, 1] * yscale, c=color_result, s=dotsize,
#    1274                                     alpha=valphadot, marker=markerdot)
#    1275                         plt.legend(handles=s.legend_elements()[0], labels=list(unique_class), loc=legendpos)
#
# NameError: name 'color_result' is not defined
